# %%
import pandas as pd 
import pickle
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge 
from sklearn.metrics import mean_squared_error
import mlflow
from pathlib import Path

import xgboost as xgb 
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from  hyperopt.pyll import scope

# %%
# specify mlflow -- use remote tracing server
mlflow.set_tracking_uri("http://ec2-44-201-134-182.compute-1.amazonaws.com:5000")
mlflow.set_experiment("nyc-taxi")
# Out:
# <Experiment: artifact_location='s3://akg-mlflow-artifact-store/2', creation_time=1685647418849, experiment_id='2', last_update_time=1685647418849, lifecycle_stage='active', name='nyc-taxi', tags={}>

# %%
# function to read parquet datasets
def read_dataframe(filename):
    df = pd.read_parquet(filename)
    
    # preprocess 
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime 
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
# pull training and validation sets
data_path = Path('../data/')
df_train = read_dataframe(filename = data_path/'green_tripdata_2022-01.parquet')
df_val = read_dataframe(filename = data_path/'green_tripdata_2022-02.parquet')
len(df_train), len(df_val)
# Out:
# (59603, 66097)

# %%
# combine pick up and drop off into one feature
df_train['PU_DO'] = df_train['PULocationID'] + '-' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '-' + df_val['DOLocationID']

# %%
categorical = ['PU_DO']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
type(X_train) # sparse matrix
# Out:
# scipy.sparse._csr.csr_matrix

# %%
# if models can handle sparse arrays, we can skip this
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
# set up linear regression
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 6.928931234319288

# %%
# ensure models folder exists 
Path('../models').mkdir(exist_ok=True)

# save model
with open('../models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
# mlflow run
with mlflow.start_run():
    mlflow.set_tag('developer', 'akg')
    mlflow.log_param('train-data-path', '../data/green_tripdata_2022-01.parquet')
    mlflow.log_param('valid-data-path', '../data/green_tripdata_2022-02.parquet')
    
    alpha = 0.1
    mlflow.log_param('alpha', alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)
    
    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric('rmse', rmse)
    mlflow.log_artifact(local_path='../models/lin_reg.bin', artifact_path='models_pickle')

# %%
# train model with xgboost and hyperparam tuning
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
# specify objective to optimize 
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag('model', 'xgboost')
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric('rmse', rmse)
    return {'loss': rmse, 'status': STATUS_OK}

# %%
# specify search space
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 23
}

# best results
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [15:40:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.97753
# [1]	validation-rmse:14.67780
# [2]	validation-rmse:13.52945
# [3]	validation-rmse:12.51776
# [4]	validation-rmse:11.62825
# [5]	validation-rmse:10.85035
# [6]	validation-rmse:10.17134
# [7]	validation-rmse:9.58134
# [8]	validation-rmse:9.07084
# [9]	validation-rmse:8.63001
# [10]	validation-rmse:8.24991
# [11]	validation-rmse:7.92442
# [12]	validation-rmse:7.64646
# [13]	validation-rmse:7.40878
# [14]	validation-rmse:7.20724
# [15]	validation-rmse:7.03668
# [16]	validation-rmse:6.89197
# [17]	validation-rmse:6.76815
# [18]	validation-rmse:6.66473
# [19]	validation-rmse:6.57615
# [20]	validation-rmse:6.50137
# [21]	validation-rmse:6.43778
# [22]	validation-rmse:6.38371
# [23]	validation-rmse:6.33762
# [24]	validation-rmse:6.29837
# [25]	validation-rmse:6.26509
# [26]	validation-rmse:6.23491
# [27]	validation-rmse:6.20909
# [28]	validation-rmse:6.18758
# [29]	validation-rmse:6.16904
# [30]	validation-rmse:6.15126
# [31]	validation-rmse:6.13559
# [32]	validation-rmse:6.12287
# [33]	validation-rmse:6.11103
# [34]	validation-rmse:6.10147
# [35]	validation-rmse:6.09240
# [36]	validation-rmse:6.08378
# [37]	validation-rmse:6.07726
# [38]	validation-rmse:6.07115
# [39]	validation-rmse:6.06516
# [40]	validation-rmse:6.06045
# [41]	validation-rmse:6.05664
# [42]	validation-rmse:6.05269
# [43]	validation-rmse:6.04880
# [44]	validation-rmse:6.04538
# [45]	validation-rmse:6.03941
# [46]	validation-rmse:6.03695
# [47]	validation-rmse:6.03187
# [48]	validation-rmse:6.02731
# [49]	validation-rmse:6.02364
# [50]	validation-rmse:6.02049
# [51]	validation-rmse:6.01611
# [52]	validation-rmse:6.01269
# [53]	validation-rmse:6.01025
# [54]	validation-rmse:6.00883
# [55]	validation-rmse:6.00670
# [56]	validation-rmse:6.00537
# [57]	validation-rmse:6.00386
# [58]	validation-rmse:6.00257
# [59]	validation-rmse:6.00137
# [60]	validation-rmse:6.00057
# [61]	validation-rmse:5.99931
# [62]	validation-rmse:5.99864
# [63]	validation-rmse:5.99818
# [64]	validation-rmse:5.99780
# [65]	validation-rmse:5.99710
# [66]	validation-rmse:5.99636
# [67]	validation-rmse:5.99570
# [68]	validation-rmse:5.99533
# [69]	validation-rmse:5.99441
# [70]	validation-rmse:5.99430
# [71]	validation-rmse:5.99378
# [72]	validation-rmse:5.99355
# [73]	validation-rmse:5.99264
# [74]	validation-rmse:5.99259
# [75]	validation-rmse:5.99231
# [76]	validation-rmse:5.99153
# [77]	validation-rmse:5.99174
# [78]	validation-rmse:5.99114
# [79]	validation-rmse:5.99104
# [80]	validation-rmse:5.99061
# [81]	validation-rmse:5.99049
# [82]	validation-rmse:5.99063
# [83]	validation-rmse:5.98953
# [84]	validation-rmse:5.98941
# [85]	validation-rmse:5.98896
# [86]	validation-rmse:5.98826
# [87]	validation-rmse:5.98844
# [88]	validation-rmse:5.98829
# [89]	validation-rmse:5.98821
# [90]	validation-rmse:5.98726
# [91]	validation-rmse:5.98702
# [92]	validation-rmse:5.98644
# [93]	validation-rmse:5.98640
# [94]	validation-rmse:5.98648
# [95]	validation-rmse:5.98566
# [96]	validation-rmse:5.98572
# [97]	validation-rmse:5.98553
# [98]	validation-rmse:5.98554
# [99]	validation-rmse:5.98561
# [15:40:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.13360
# [1]	validation-rmse:13.23834
# [2]	validation-rmse:11.69684
# [3]	validation-rmse:10.46002
# [4]	validation-rmse:9.46757
# [5]	validation-rmse:8.68029
# [6]	validation-rmse:8.05808
# [7]	validation-rmse:7.57946
# [8]	validation-rmse:7.20098
# [9]	validation-rmse:6.91145
# [10]	validation-rmse:6.68879
# [11]	validation-rmse:6.51549
# [12]	validation-rmse:6.38320
# [13]	validation-rmse:6.27921
# [14]	validation-rmse:6.20045
# [15]	validation-rmse:6.13639
# [16]	validation-rmse:6.08678
# [17]	validation-rmse:6.04631
# [18]	validation-rmse:6.01610
# [19]	validation-rmse:5.98969
# [20]	validation-rmse:5.97014
# [21]	validation-rmse:5.95250
# [22]	validation-rmse:5.93818
# [23]	validation-rmse:5.92599
# [24]	validation-rmse:5.91816
# [25]	validation-rmse:5.91112
# [26]	validation-rmse:5.90664
# [27]	validation-rmse:5.90360
# [28]	validation-rmse:5.89713
# [29]	validation-rmse:5.89438
# [30]	validation-rmse:5.89092
# [31]	validation-rmse:5.88882
# [32]	validation-rmse:5.88448
# [33]	validation-rmse:5.88329
# [34]	validation-rmse:5.88234
# [35]	validation-rmse:5.88006
# [36]	validation-rmse:5.87938
# [37]	validation-rmse:5.87787
# [38]	validation-rmse:5.87618
# [39]	validation-rmse:5.87502
# [40]	validation-rmse:5.87238
# [41]	validation-rmse:5.87102
# [42]	validation-rmse:5.86985
# [43]	validation-rmse:5.86760
# [44]	validation-rmse:5.86627
# [45]	validation-rmse:5.86569
# [46]	validation-rmse:5.86484
# [47]	validation-rmse:5.86414
# [48]	validation-rmse:5.86347
# [49]	validation-rmse:5.86318
# [50]	validation-rmse:5.86315
# [51]	validation-rmse:5.86215
# [52]	validation-rmse:5.86144
# [53]	validation-rmse:5.86026
# [54]	validation-rmse:5.85894
# [55]	validation-rmse:5.85857
# [56]	validation-rmse:5.85827
# [57]	validation-rmse:5.85771
# [58]	validation-rmse:5.85721
# [59]	validation-rmse:5.85613
# [60]	validation-rmse:5.85582
# [61]	validation-rmse:5.85501
# [62]	validation-rmse:5.85456
# [63]	validation-rmse:5.85353
# [64]	validation-rmse:5.85259
# [65]	validation-rmse:5.85214
# [66]	validation-rmse:5.85236
# [67]	validation-rmse:5.85149
# [68]	validation-rmse:5.85140
# [69]	validation-rmse:5.85117
# [70]	validation-rmse:5.85080
# [71]	validation-rmse:5.85032
# [72]	validation-rmse:5.85013
# [73]	validation-rmse:5.84951
# [74]	validation-rmse:5.84895
# [75]	validation-rmse:5.84851
# [76]	validation-rmse:5.84816
# [77]	validation-rmse:5.84776
# [78]	validation-rmse:5.84734
# [79]	validation-rmse:5.84650
# [80]	validation-rmse:5.84600
# [81]	validation-rmse:5.84605
# [82]	validation-rmse:5.84542
# [83]	validation-rmse:5.84521
# [84]	validation-rmse:5.84448
# [85]	validation-rmse:5.84426
# [86]	validation-rmse:5.84360
# [87]	validation-rmse:5.84341
# [88]	validation-rmse:5.84352
# [89]	validation-rmse:5.84267
# [90]	validation-rmse:5.84271
# [91]	validation-rmse:5.84225
# [92]	validation-rmse:5.84163
# [93]	validation-rmse:5.84129
# [94]	validation-rmse:5.84143
# [95]	validation-rmse:5.84130
# [96]	validation-rmse:5.84058
# [97]	validation-rmse:5.84038
# [98]	validation-rmse:5.84034
# [99]	validation-rmse:5.84033
# [15:40:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:11.76110
# [1]	validation-rmse:8.75199
# [2]	validation-rmse:7.27048
# [3]	validation-rmse:6.57876
# [4]	validation-rmse:6.25863
# [5]	validation-rmse:6.09819
# [6]	validation-rmse:6.01641
# [7]	validation-rmse:5.97813
# [8]	validation-rmse:5.95598
# [9]	validation-rmse:5.94803
# [10]	validation-rmse:5.94127
# [11]	validation-rmse:5.93419
# [12]	validation-rmse:5.92302
# [13]	validation-rmse:5.92066
# [14]	validation-rmse:5.91625
# [15]	validation-rmse:5.91319
# [16]	validation-rmse:5.91326
# [17]	validation-rmse:5.91089
# [18]	validation-rmse:5.90853
# [19]	validation-rmse:5.90537
# [20]	validation-rmse:5.90357
# [21]	validation-rmse:5.89647
# [22]	validation-rmse:5.89478
# [23]	validation-rmse:5.89384
# [24]	validation-rmse:5.89205
# [25]	validation-rmse:5.89077
# [26]	validation-rmse:5.88774
# [27]	validation-rmse:5.88482
# [28]	validation-rmse:5.88313
# [29]	validation-rmse:5.88287
# [30]	validation-rmse:5.88263
# [31]	validation-rmse:5.88128
# [32]	validation-rmse:5.88145
# [33]	validation-rmse:5.88015
# [34]	validation-rmse:5.87970
# [35]	validation-rmse:5.87825
# [36]	validation-rmse:5.87726
# [37]	validation-rmse:5.87562
# [38]	validation-rmse:5.87418
# [39]	validation-rmse:5.87433
# [40]	validation-rmse:5.87397
# [41]	validation-rmse:5.87369
# [42]	validation-rmse:5.87287
# [43]	validation-rmse:5.87281
# [44]	validation-rmse:5.87045
# [45]	validation-rmse:5.86781
# [46]	validation-rmse:5.86785
# [47]	validation-rmse:5.86552
# [48]	validation-rmse:5.86488
# [49]	validation-rmse:5.86438
# [50]	validation-rmse:5.86384
# [51]	validation-rmse:5.86283
# [52]	validation-rmse:5.86218
# [53]	validation-rmse:5.86048
# [54]	validation-rmse:5.85502
# [55]	validation-rmse:5.85470
# [56]	validation-rmse:5.85359
# [57]	validation-rmse:5.85345
# [58]	validation-rmse:5.85225
# [59]	validation-rmse:5.85160
# [60]	validation-rmse:5.85208
# [61]	validation-rmse:5.85231
# [62]	validation-rmse:5.85197
# [63]	validation-rmse:5.85121
# [64]	validation-rmse:5.85068
# [65]	validation-rmse:5.85157
# [66]	validation-rmse:5.85138
# [67]	validation-rmse:5.85139
# [68]	validation-rmse:5.85172
# [69]	validation-rmse:5.85090
# [70]	validation-rmse:5.85122
# [71]	validation-rmse:5.85212
# [72]	validation-rmse:5.85155
# [73]	validation-rmse:5.85084
# [74]	validation-rmse:5.85125
# [75]	validation-rmse:5.85102
# [76]	validation-rmse:5.85114
# [77]	validation-rmse:5.85139
# [78]	validation-rmse:5.85188
# [79]	validation-rmse:5.85077
# [80]	validation-rmse:5.85036
# [81]	validation-rmse:5.85074
# [82]	validation-rmse:5.85012
# [83]	validation-rmse:5.85096
# [84]	validation-rmse:5.85098
# [85]	validation-rmse:5.85075
# [86]	validation-rmse:5.84769
# [87]	validation-rmse:5.84796
# [88]	validation-rmse:5.84799
# [89]	validation-rmse:5.84745
# [90]	validation-rmse:5.84754
# [91]	validation-rmse:5.84777
# [92]	validation-rmse:5.84847
# [93]	validation-rmse:5.84410
# [94]	validation-rmse:5.84428
# [95]	validation-rmse:5.84449
# [96]	validation-rmse:5.84415
# [97]	validation-rmse:5.84412
# [98]	validation-rmse:5.84376
# [99]	validation-rmse:5.84326
# [15:40:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.99607
# [1]	validation-rmse:14.70998
# [2]	validation-rmse:13.57269
# [3]	validation-rmse:12.56710
# [4]	validation-rmse:11.68202
# [5]	validation-rmse:10.90463
# [6]	validation-rmse:10.22419
# [7]	validation-rmse:9.63202
# [8]	validation-rmse:9.11840
# [9]	validation-rmse:8.67199
# [10]	validation-rmse:8.28789
# [11]	validation-rmse:7.95711
# [12]	validation-rmse:7.67344
# [13]	validation-rmse:7.42966
# [14]	validation-rmse:7.22376
# [15]	validation-rmse:7.04724
# [16]	validation-rmse:6.89662
# [17]	validation-rmse:6.76848
# [18]	validation-rmse:6.65994
# [19]	validation-rmse:6.56699
# [20]	validation-rmse:6.48795
# [21]	validation-rmse:6.41876
# [22]	validation-rmse:6.36024
# [23]	validation-rmse:6.31005
# [24]	validation-rmse:6.26670
# [25]	validation-rmse:6.23064
# [26]	validation-rmse:6.19863
# [27]	validation-rmse:6.17171
# [28]	validation-rmse:6.14746
# [29]	validation-rmse:6.12686
# [30]	validation-rmse:6.10902
# [31]	validation-rmse:6.09352
# [32]	validation-rmse:6.07900
# [33]	validation-rmse:6.06632
# [34]	validation-rmse:6.05618
# [35]	validation-rmse:6.04661
# [36]	validation-rmse:6.03747
# [37]	validation-rmse:6.02935
# [38]	validation-rmse:6.02253
# [39]	validation-rmse:6.01624
# [40]	validation-rmse:6.01057
# [41]	validation-rmse:6.00545
# [42]	validation-rmse:6.00089
# [43]	validation-rmse:5.99647
# [44]	validation-rmse:5.99217
# [45]	validation-rmse:5.98800
# [46]	validation-rmse:5.98466
# [47]	validation-rmse:5.97900
# [48]	validation-rmse:5.97476
# [49]	validation-rmse:5.97262
# [50]	validation-rmse:5.96894
# [51]	validation-rmse:5.96632
# [52]	validation-rmse:5.96462
# [53]	validation-rmse:5.96079
# [54]	validation-rmse:5.95857
# [55]	validation-rmse:5.95687
# [56]	validation-rmse:5.95551
# [57]	validation-rmse:5.95271
# [58]	validation-rmse:5.94998
# [59]	validation-rmse:5.94895
# [60]	validation-rmse:5.94737
# [61]	validation-rmse:5.94571
# [62]	validation-rmse:5.94437
# [63]	validation-rmse:5.94366
# [64]	validation-rmse:5.94179
# [65]	validation-rmse:5.94038
# [66]	validation-rmse:5.93926
# [67]	validation-rmse:5.93851
# [68]	validation-rmse:5.93793
# [69]	validation-rmse:5.93732
# [70]	validation-rmse:5.93696
# [71]	validation-rmse:5.93617
# [72]	validation-rmse:5.93542
# [73]	validation-rmse:5.93497
# [74]	validation-rmse:5.93455
# [75]	validation-rmse:5.93427
# [76]	validation-rmse:5.93405
# [77]	validation-rmse:5.93376
# [78]	validation-rmse:5.93189
# [79]	validation-rmse:5.93139
# [80]	validation-rmse:5.93075
# [81]	validation-rmse:5.93025
# [82]	validation-rmse:5.92995
# [83]	validation-rmse:5.92979
# [84]	validation-rmse:5.92945
# [85]	validation-rmse:5.92916
# [86]	validation-rmse:5.92890
# [87]	validation-rmse:5.92877
# [88]	validation-rmse:5.92799
# [89]	validation-rmse:5.92773
# [90]	validation-rmse:5.92737
# [91]	validation-rmse:5.92688
# [92]	validation-rmse:5.92631
# [93]	validation-rmse:5.92610
# [94]	validation-rmse:5.92598
# [95]	validation-rmse:5.92592
# [96]	validation-rmse:5.92572
# [97]	validation-rmse:5.92525
# [98]	validation-rmse:5.92506
# [99]	validation-rmse:5.92492
# [15:41:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.74854
# [1]	validation-rmse:14.27879
# [2]	validation-rmse:13.00731
# [3]	validation-rmse:11.91643
# [4]	validation-rmse:10.98291
# [5]	validation-rmse:10.17605
# [6]	validation-rmse:9.50051
# [7]	validation-rmse:8.91435
# [8]	validation-rmse:8.44132
# [9]	validation-rmse:8.03975
# [10]	validation-rmse:7.69476
# [11]	validation-rmse:7.41570
# [12]	validation-rmse:7.18017
# [13]	validation-rmse:6.98635
# [14]	validation-rmse:6.82440
# [15]	validation-rmse:6.68793
# [16]	validation-rmse:6.58187
# [17]	validation-rmse:6.48657
# [18]	validation-rmse:6.41370
# [19]	validation-rmse:6.34707
# [20]	validation-rmse:6.29837
# [21]	validation-rmse:6.25320
# [22]	validation-rmse:6.21459
# [23]	validation-rmse:6.18458
# [24]	validation-rmse:6.15445
# [25]	validation-rmse:6.13628
# [26]	validation-rmse:6.11876
# [27]	validation-rmse:6.10004
# [28]	validation-rmse:6.08396
# [29]	validation-rmse:6.07145
# [30]	validation-rmse:6.06148
# [31]	validation-rmse:6.05129
# [32]	validation-rmse:6.04342
# [33]	validation-rmse:6.03566
# [34]	validation-rmse:6.02991
# [35]	validation-rmse:6.02464
# [36]	validation-rmse:6.01993
# [37]	validation-rmse:6.01477
# [38]	validation-rmse:6.01143
# [39]	validation-rmse:6.00870
# [40]	validation-rmse:6.00649
# [41]	validation-rmse:6.00478
# [42]	validation-rmse:6.00199
# [43]	validation-rmse:5.99816
# [44]	validation-rmse:5.99522
# [45]	validation-rmse:5.99343
# [46]	validation-rmse:5.99203
# [47]	validation-rmse:5.99031
# [48]	validation-rmse:5.98948
# [49]	validation-rmse:5.98801
# [50]	validation-rmse:5.98761
# [51]	validation-rmse:5.98661
# [52]	validation-rmse:5.98606
# [53]	validation-rmse:5.98441
# [54]	validation-rmse:5.98404
# [55]	validation-rmse:5.98318
# [56]	validation-rmse:5.98262
# [57]	validation-rmse:5.98168
# [58]	validation-rmse:5.98105
# [59]	validation-rmse:5.98034
# [60]	validation-rmse:5.97968
# [61]	validation-rmse:5.97939
# [62]	validation-rmse:5.97924
# [63]	validation-rmse:5.97861
# [64]	validation-rmse:5.97827
# [65]	validation-rmse:5.97791
# [66]	validation-rmse:5.97733
# [67]	validation-rmse:5.97733
# [68]	validation-rmse:5.97638
# [69]	validation-rmse:5.97631
# [70]	validation-rmse:5.97535
# [71]	validation-rmse:5.97529
# [72]	validation-rmse:5.97507
# [73]	validation-rmse:5.97527
# [74]	validation-rmse:5.97478
# [75]	validation-rmse:5.97441
# [76]	validation-rmse:5.97406
# [77]	validation-rmse:5.97414
# [78]	validation-rmse:5.97311
# [79]	validation-rmse:5.97292
# [80]	validation-rmse:5.97236
# [81]	validation-rmse:5.97232
# [82]	validation-rmse:5.97204
# [83]	validation-rmse:5.97144
# [84]	validation-rmse:5.97157
# [85]	validation-rmse:5.97164
# [86]	validation-rmse:5.97078
# [87]	validation-rmse:5.97029
# [88]	validation-rmse:5.96960
# [89]	validation-rmse:5.96945
# [90]	validation-rmse:5.96844
# [91]	validation-rmse:5.96829
# [92]	validation-rmse:5.96815
# [93]	validation-rmse:5.96792
# [94]	validation-rmse:5.96751
# [95]	validation-rmse:5.96643
# [96]	validation-rmse:5.96612
# [97]	validation-rmse:5.96604
# [98]	validation-rmse:5.96563
# [99]	validation-rmse:5.96485
# [15:41:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:13.80557
# [1]	validation-rmse:11.23365
# [2]	validation-rmse:9.45666
# [3]	validation-rmse:8.25128
# [4]	validation-rmse:7.47173
# [5]	validation-rmse:6.95681
# [6]	validation-rmse:6.62486
# [7]	validation-rmse:6.41199
# [8]	validation-rmse:6.27767
# [9]	validation-rmse:6.18318
# [10]	validation-rmse:6.11666
# [11]	validation-rmse:6.06775
# [12]	validation-rmse:6.03878
# [13]	validation-rmse:6.01617
# [14]	validation-rmse:5.99849
# [15]	validation-rmse:5.98917
# [16]	validation-rmse:5.98195
# [17]	validation-rmse:5.97808
# [18]	validation-rmse:5.97522
# [19]	validation-rmse:5.97136
# [20]	validation-rmse:5.96825
# [21]	validation-rmse:5.96669
# [22]	validation-rmse:5.96484
# [23]	validation-rmse:5.96399
# [24]	validation-rmse:5.96147
# [25]	validation-rmse:5.96021
# [26]	validation-rmse:5.95956
# [27]	validation-rmse:5.95815
# [28]	validation-rmse:5.95508
# [29]	validation-rmse:5.95125
# [30]	validation-rmse:5.95074
# [31]	validation-rmse:5.95044
# [32]	validation-rmse:5.94860
# [33]	validation-rmse:5.94784
# [34]	validation-rmse:5.94683
# [35]	validation-rmse:5.94590
# [36]	validation-rmse:5.94299
# [37]	validation-rmse:5.94129
# [38]	validation-rmse:5.93993
# [39]	validation-rmse:5.93841
# [40]	validation-rmse:5.93710
# [41]	validation-rmse:5.93608
# [42]	validation-rmse:5.93560
# [43]	validation-rmse:5.93431
# [44]	validation-rmse:5.93331
# [45]	validation-rmse:5.93216
# [46]	validation-rmse:5.93096
# [47]	validation-rmse:5.93031
# [48]	validation-rmse:5.92997
# [49]	validation-rmse:5.92917
# [50]	validation-rmse:5.92701
# [51]	validation-rmse:5.92727
# [52]	validation-rmse:5.92656
# [53]	validation-rmse:5.92665
# [54]	validation-rmse:5.92569
# [55]	validation-rmse:5.92507
# [56]	validation-rmse:5.92459
# [57]	validation-rmse:5.92323
# [58]	validation-rmse:5.92372
# [59]	validation-rmse:5.92322
# [60]	validation-rmse:5.92289
# [61]	validation-rmse:5.92173
# [62]	validation-rmse:5.92057
# [63]	validation-rmse:5.91879
# [64]	validation-rmse:5.91792
# [65]	validation-rmse:5.91692
# [66]	validation-rmse:5.91583
# [67]	validation-rmse:5.91433
# [68]	validation-rmse:5.91351
# [69]	validation-rmse:5.91338
# [70]	validation-rmse:5.91298
# [71]	validation-rmse:5.91281
# [72]	validation-rmse:5.91257
# [73]	validation-rmse:5.91134
# [74]	validation-rmse:5.91004
# [75]	validation-rmse:5.90967
# [76]	validation-rmse:5.90893
# [77]	validation-rmse:5.90860
# [78]	validation-rmse:5.90742
# [79]	validation-rmse:5.90717
# [80]	validation-rmse:5.90652
# [81]	validation-rmse:5.90526
# [82]	validation-rmse:5.90457
# [83]	validation-rmse:5.90422
# [84]	validation-rmse:5.90381
# [85]	validation-rmse:5.90231
# [86]	validation-rmse:5.90121
# [87]	validation-rmse:5.90151
# [88]	validation-rmse:5.90107
# [89]	validation-rmse:5.90178
# [90]	validation-rmse:5.90105
# [91]	validation-rmse:5.90121
# [92]	validation-rmse:5.90094
# [93]	validation-rmse:5.90093
# [94]	validation-rmse:5.90050
# [95]	validation-rmse:5.90124
# [96]	validation-rmse:5.90061
# [97]	validation-rmse:5.90092
# [98]	validation-rmse:5.90109
# [99]	validation-rmse:5.90093
# [15:41:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:11.85449
# [1]	validation-rmse:8.85359
# [2]	validation-rmse:7.36124
# [3]	validation-rmse:6.66330
# [4]	validation-rmse:6.33449
# [5]	validation-rmse:6.17959
# [6]	validation-rmse:6.10177
# [7]	validation-rmse:6.06024
# [8]	validation-rmse:6.03190
# [9]	validation-rmse:6.01589
# [10]	validation-rmse:5.99596
# [11]	validation-rmse:5.98829
# ...
# [7]	validation-rmse:5.99018
# [8]	validation-rmse:5.98754
# [9]	validation-rmse:5.98330
# [10]	validation-rmse:5.97292
# [11]	validation-rmse:5.96997
# [12]	validation-rmse:5.96934
# [13]	validation-rmse:5.96591
# [14]	validation-rmse:5.96388
# [15]	validation-rmse:5.96293
# [16]	validation-rmse:5.96072
# [17]	validation-rmse:5.95779
# [18]	validation-rmse:5.95726
# [19]	validation-rmse:5.95635
# [20]	validation-rmse:5.95381
# [21]	validation-rmse:5.95318
# [22]	validation-rmse:5.95162
# [23]	validation-rmse:5.95058
# [24]	validation-rmse:5.94976
# [25]	validation-rmse:5.94710
# [26]	validation-rmse:5.94511
# [27]	validation-rmse:5.94382
# [28]	validation-rmse:5.94256
# [29]	validation-rmse:5.93932
# [30]	validation-rmse:5.93613
# [31]	validation-rmse:5.93570
# [32]	validation-rmse:5.93327
# [33]	validation-rmse:5.93258
# [34]	validation-rmse:5.93024
# [35]	validation-rmse:5.92871
# [36]	validation-rmse:5.92669
# [37]	validation-rmse:5.92588
# [38]	validation-rmse:5.91375
# [39]	validation-rmse:5.91245
# [40]	validation-rmse:5.91220
# [41]	validation-rmse:5.91059
# [42]	validation-rmse:5.90865
# [43]	validation-rmse:5.90892
# [44]	validation-rmse:5.90851
# [45]	validation-rmse:5.90707
# [46]	validation-rmse:5.90730
# [47]	validation-rmse:5.90772
# [48]	validation-rmse:5.90574
# [49]	validation-rmse:5.90485
# [50]	validation-rmse:5.89699
# [51]	validation-rmse:5.89691
# [52]	validation-rmse:5.89508
# [53]	validation-rmse:5.89535
# [54]	validation-rmse:5.89493
# [55]	validation-rmse:5.89295
# [56]	validation-rmse:5.89165
# [57]	validation-rmse:5.89096
# [58]	validation-rmse:5.89013
# [59]	validation-rmse:5.88854
# [60]	validation-rmse:5.88682
# [61]	validation-rmse:5.88589
# [62]	validation-rmse:5.88534
# [63]	validation-rmse:5.88407
# [64]	validation-rmse:5.87818
# [65]	validation-rmse:5.87798
# [66]	validation-rmse:5.87827
# [67]	validation-rmse:5.87787
# [68]	validation-rmse:5.87870
# [69]	validation-rmse:5.87879
# [70]	validation-rmse:5.87912
# [71]	validation-rmse:5.87899
# [72]	validation-rmse:5.87735
# [73]	validation-rmse:5.87653
# [74]	validation-rmse:5.87396
# [75]	validation-rmse:5.87354
# [76]	validation-rmse:5.87415
# [77]	validation-rmse:5.87414
# [78]	validation-rmse:5.87360
# [79]	validation-rmse:5.87479
# [80]	validation-rmse:5.87348
# [81]	validation-rmse:5.87220
# [82]	validation-rmse:5.87148
# [83]	validation-rmse:5.87107
# [84]	validation-rmse:5.87240
# [85]	validation-rmse:5.87160
# [86]	validation-rmse:5.86638
# [87]	validation-rmse:5.86669
# [88]	validation-rmse:5.86671
# [89]	validation-rmse:5.86622
# [90]	validation-rmse:5.86557
# [91]	validation-rmse:5.86636
# [92]	validation-rmse:5.86585
# [93]	validation-rmse:5.86544
# [94]	validation-rmse:5.86584
# [95]	validation-rmse:5.86517
# [96]	validation-rmse:5.86410
# [97]	validation-rmse:5.86406
# [98]	validation-rmse:5.86405
# [99]	validation-rmse:5.86467
# [15:46:56] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:11.47952
# [1]	validation-rmse:8.46394
# [2]	validation-rmse:7.06210
# [3]	validation-rmse:6.44494
# [4]	validation-rmse:6.17406
# [5]	validation-rmse:6.05055
# [6]	validation-rmse:5.98213
# [7]	validation-rmse:5.94485
# [8]	validation-rmse:5.92535
# [9]	validation-rmse:5.91154
# [10]	validation-rmse:5.90385
# [11]	validation-rmse:5.89957
# [12]	validation-rmse:5.89451
# [13]	validation-rmse:5.89229
# [14]	validation-rmse:5.88803
# [15]	validation-rmse:5.88765
# [16]	validation-rmse:5.88404
# [17]	validation-rmse:5.88310
# [18]	validation-rmse:5.88168
# [19]	validation-rmse:5.88022
# [20]	validation-rmse:5.87681
# [21]	validation-rmse:5.87515
# [22]	validation-rmse:5.87336
# [23]	validation-rmse:5.87120
# [24]	validation-rmse:5.86487
# [25]	validation-rmse:5.86464
# [26]	validation-rmse:5.86311
# [27]	validation-rmse:5.86232
# [28]	validation-rmse:5.86122
# [29]	validation-rmse:5.86093
# [30]	validation-rmse:5.85967
# [31]	validation-rmse:5.85990
# [32]	validation-rmse:5.85757
# [33]	validation-rmse:5.85834
# [34]	validation-rmse:5.85826
# [35]	validation-rmse:5.85800
# [36]	validation-rmse:5.85210
# [37]	validation-rmse:5.85223
# [38]	validation-rmse:5.85179
# [39]	validation-rmse:5.85268
# [40]	validation-rmse:5.85266
# [41]	validation-rmse:5.85130
# [42]	validation-rmse:5.85174
# [43]	validation-rmse:5.85143
# [44]	validation-rmse:5.85157
# [45]	validation-rmse:5.85106
# [46]	validation-rmse:5.85083
# [47]	validation-rmse:5.85124
# [48]	validation-rmse:5.85183
# [49]	validation-rmse:5.85215
# [50]	validation-rmse:5.85139
# [51]	validation-rmse:5.85093
# [52]	validation-rmse:5.85084
# [53]	validation-rmse:5.85089
# [54]	validation-rmse:5.85010
# [55]	validation-rmse:5.85227
# [56]	validation-rmse:5.85444
# [57]	validation-rmse:5.85465
# [58]	validation-rmse:5.85467
# [59]	validation-rmse:5.85558
# [60]	validation-rmse:5.85549
# [61]	validation-rmse:5.85511
# [62]	validation-rmse:5.85373
# [63]	validation-rmse:5.85322
# [64]	validation-rmse:5.85295
# [65]	validation-rmse:5.85246
# [66]	validation-rmse:5.85250
# [67]	validation-rmse:5.85239
# [68]	validation-rmse:5.85247
# [69]	validation-rmse:5.85144
# [70]	validation-rmse:5.85054
# [71]	validation-rmse:5.85048
# [72]	validation-rmse:5.85090
# [73]	validation-rmse:5.85061
# [74]	validation-rmse:5.85122
# [75]	validation-rmse:5.85045
# [76]	validation-rmse:5.84988
# [77]	validation-rmse:5.84993
# [78]	validation-rmse:5.84980
# [79]	validation-rmse:5.84992
# [80]	validation-rmse:5.85049
# [81]	validation-rmse:5.85130
# [82]	validation-rmse:5.85108
# [83]	validation-rmse:5.85306
# [84]	validation-rmse:5.85399
# [85]	validation-rmse:5.85412
# [86]	validation-rmse:5.85443
# [87]	validation-rmse:5.85535
# [88]	validation-rmse:5.85591
# [89]	validation-rmse:5.85553
# [90]	validation-rmse:5.85593
# [91]	validation-rmse:5.85652
# [92]	validation-rmse:5.85761
# [93]	validation-rmse:5.85768
# [94]	validation-rmse:5.85758
# [95]	validation-rmse:5.85807
# [96]	validation-rmse:5.85859
# [97]	validation-rmse:5.85740
# [98]	validation-rmse:5.85707
# [99]	validation-rmse:5.85689
# 100%|██████████| 50/50 [06:37<00:00,  7.94s/trial, best loss: 5.820941225540314]
