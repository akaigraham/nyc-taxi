# %%
import pandas as pd 
import pickle
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge 
from sklearn.metrics import mean_squared_error
import mlflow
from pathlib import Path

import xgboost as xgb 
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from  hyperopt.pyll import scope

# %%
# specify mlflow -- use remote tracing server
mlflow.set_tracking_uri("http://ec2-44-201-134-182.compute-1.amazonaws.com:5000")
mlflow.set_experiment("nyc-taxi")
# Out:
# <Experiment: artifact_location='s3://akg-mlflow-artifact-store/2', creation_time=1685647418849, experiment_id='2', last_update_time=1685647418849, lifecycle_stage='active', name='nyc-taxi', tags={}>

# %%
# function to read parquet datasets
def read_dataframe(filename):
    df = pd.read_parquet(filename)
    
    # preprocess 
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime 
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
# pull training and validation sets
data_path = Path('../data/')
df_train = read_dataframe(filename = data_path/'green_tripdata_2022-01.parquet')
df_val = read_dataframe(filename = data_path/'green_tripdata_2022-02.parquet')
len(df_train), len(df_val)
# Out:
# (59603, 66097)

# %%
# combine pick up and drop off into one feature
df_train['PU_DO'] = df_train['PULocationID'] + '-' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '-' + df_val['DOLocationID']

# %%
categorical = ['PU_DO']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
type(X_train) # sparse matrix
# Out:
# scipy.sparse._csr.csr_matrix

# %%
# if models can handle sparse arrays, we can skip this
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
# set up linear regression
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 6.928931234319288

# %%
# ensure models folder exists 
Path('../models').mkdir(exist_ok=True)

# save model
with open('../models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
# mlflow run
with mlflow.start_run():
    mlflow.set_tag('developer', 'akg')
    mlflow.log_param('train-data-path', '../data/green_tripdata_2022-01.parquet')
    mlflow.log_param('valid-data-path', '../data/green_tripdata_2022-02.parquet')
    
    alpha = 0.1
    mlflow.log_param('alpha', alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)
    
    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric('rmse', rmse)
    mlflow.log_artifact(local_path='../models/lin_reg.bin', artifact_path='models_pickle')

# %%
# train model with xgboost and hyperparam tuning
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
# specify objective to optimize 
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag('model', 'xgboost')
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric('rmse', rmse)
    return {'loss': rmse, 'status': STATUS_OK}

# %%
# specify search space
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 23
}

# best results
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [14:25:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.95642
# [1]	validation-rmse:14.64066
# [2]	validation-rmse:13.48029
# [3]	validation-rmse:12.46089
# [4]	validation-rmse:11.56707
# [5]	validation-rmse:10.78701
# [6]	validation-rmse:10.10791
# [7]	validation-rmse:9.51991
# [8]	validation-rmse:9.01130
# [9]	validation-rmse:8.57380
# [10]	validation-rmse:8.19926
# [11]	validation-rmse:7.87867
# [12]	validation-rmse:7.60574
# [13]	validation-rmse:7.37467
# [14]	validation-rmse:7.17701
# [15]	validation-rmse:7.01106
# [16]	validation-rmse:6.87050
# [17]	validation-rmse:6.75262
# [18]	validation-rmse:6.65206
# [19]	validation-rmse:6.56830
# [20]	validation-rmse:6.49563
# [21]	validation-rmse:6.43456
# [22]	validation-rmse:6.38229
# [23]	validation-rmse:6.33694
# [24]	validation-rmse:6.29656
# [25]	validation-rmse:6.26314
# [26]	validation-rmse:6.23435
# [27]	validation-rmse:6.20875
# [28]	validation-rmse:6.18752
# [29]	validation-rmse:6.16877
# [30]	validation-rmse:6.15313
# [31]	validation-rmse:6.13898
# [32]	validation-rmse:6.12689
# [33]	validation-rmse:6.11655
# [34]	validation-rmse:6.10765
# [35]	validation-rmse:6.09956
# [36]	validation-rmse:6.09197
# [37]	validation-rmse:6.08543
# [38]	validation-rmse:6.07949
# [39]	validation-rmse:6.07455
# [40]	validation-rmse:6.06998
# [41]	validation-rmse:6.06422
# [42]	validation-rmse:6.06051
# [43]	validation-rmse:6.05588
# [44]	validation-rmse:6.04935
# [45]	validation-rmse:6.04449
# [46]	validation-rmse:6.04108
# [47]	validation-rmse:6.03744
# [48]	validation-rmse:6.03502
# [49]	validation-rmse:6.03193
# [50]	validation-rmse:6.02911
# [51]	validation-rmse:6.02593
# [52]	validation-rmse:6.02377
# [53]	validation-rmse:6.02119
# [54]	validation-rmse:6.01876
# [55]	validation-rmse:6.01631
# [56]	validation-rmse:6.01474
# [57]	validation-rmse:6.01235
# [58]	validation-rmse:6.01145
# [59]	validation-rmse:6.01015
# [60]	validation-rmse:6.00923
# [61]	validation-rmse:6.00795
# [62]	validation-rmse:6.00747
# [63]	validation-rmse:6.00633
# [64]	validation-rmse:6.00541
# [65]	validation-rmse:6.00496
# [66]	validation-rmse:6.00341
# [67]	validation-rmse:6.00303
# [68]	validation-rmse:6.00206
# [69]	validation-rmse:6.00192
# [70]	validation-rmse:6.00100
# [71]	validation-rmse:6.00054
# [72]	validation-rmse:5.99999
# [73]	validation-rmse:5.99969
# [74]	validation-rmse:5.99963
# [75]	validation-rmse:5.99877
# [76]	validation-rmse:5.99865
# [77]	validation-rmse:5.99812
# [78]	validation-rmse:5.99795
# [79]	validation-rmse:5.99688
# [80]	validation-rmse:5.99641
# [81]	validation-rmse:5.99559
# [82]	validation-rmse:5.99550
# [83]	validation-rmse:5.99517
# [84]	validation-rmse:5.99434
# [85]	validation-rmse:5.99436
# [86]	validation-rmse:5.99372
# [87]	validation-rmse:5.99334
# [88]	validation-rmse:5.99302
# [89]	validation-rmse:5.99254
# [90]	validation-rmse:5.99253
# [91]	validation-rmse:5.99219
# [92]	validation-rmse:5.99203
# [93]	validation-rmse:5.99212
# [94]	validation-rmse:5.99157
# [95]	validation-rmse:5.99134
# [96]	validation-rmse:5.99109
# [97]	validation-rmse:5.99117
# [98]	validation-rmse:5.99097
# [99]	validation-rmse:5.99028
# [14:25:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.81962
# [1]	validation-rmse:14.40406
# [2]	validation-rmse:13.17050
# [3]	validation-rmse:12.10183
# [4]	validation-rmse:11.17961
# [5]	validation-rmse:10.38120
# [6]	validation-rmse:9.70281
# [7]	validation-rmse:9.11813
# [8]	validation-rmse:8.61774
# [9]	validation-rmse:8.20155
# [10]	validation-rmse:7.84332
# [11]	validation-rmse:7.54548
# [12]	validation-rmse:7.29410
# [13]	validation-rmse:7.08778
# [14]	validation-rmse:6.90674
# [15]	validation-rmse:6.76014
# [16]	validation-rmse:6.63349
# [17]	validation-rmse:6.52972
# [18]	validation-rmse:6.43981
# [19]	validation-rmse:6.36929
# [20]	validation-rmse:6.31142
# [21]	validation-rmse:6.26262
# [22]	validation-rmse:6.21642
# [23]	validation-rmse:6.17867
# [24]	validation-rmse:6.14505
# [25]	validation-rmse:6.11839
# [26]	validation-rmse:6.09005
# [27]	validation-rmse:6.07116
# [28]	validation-rmse:6.05120
# [29]	validation-rmse:6.03664
# [30]	validation-rmse:6.02339
# [31]	validation-rmse:6.01393
# [32]	validation-rmse:6.00458
# [33]	validation-rmse:5.99514
# [34]	validation-rmse:5.98867
# [35]	validation-rmse:5.98245
# [36]	validation-rmse:5.97669
# [37]	validation-rmse:5.97106
# [38]	validation-rmse:5.96564
# [39]	validation-rmse:5.96209
# [40]	validation-rmse:5.95866
# [41]	validation-rmse:5.95590
# [42]	validation-rmse:5.95368
# [43]	validation-rmse:5.95200
# [44]	validation-rmse:5.95054
# [45]	validation-rmse:5.94918
# [46]	validation-rmse:5.94789
# [47]	validation-rmse:5.94596
# [48]	validation-rmse:5.94472
# [49]	validation-rmse:5.94286
# [50]	validation-rmse:5.94152
# [51]	validation-rmse:5.94055
# [52]	validation-rmse:5.94016
# [53]	validation-rmse:5.93962
# [54]	validation-rmse:5.93889
# [55]	validation-rmse:5.93635
# [56]	validation-rmse:5.93585
# [57]	validation-rmse:5.93482
# [58]	validation-rmse:5.93338
# [59]	validation-rmse:5.93294
# [60]	validation-rmse:5.93242
# [61]	validation-rmse:5.93169
# [62]	validation-rmse:5.93029
# [63]	validation-rmse:5.92967
# [64]	validation-rmse:5.92897
# [65]	validation-rmse:5.92843
# [66]	validation-rmse:5.92773
# [67]	validation-rmse:5.92763
# [68]	validation-rmse:5.92747
# [69]	validation-rmse:5.92740
# [70]	validation-rmse:5.92709
# [71]	validation-rmse:5.92674
# [72]	validation-rmse:5.92656
# [73]	validation-rmse:5.92537
# [74]	validation-rmse:5.92476
# [75]	validation-rmse:5.92391
# [76]	validation-rmse:5.92326
# [77]	validation-rmse:5.92220
# [78]	validation-rmse:5.92186
# [79]	validation-rmse:5.92135
# [80]	validation-rmse:5.92096
# [81]	validation-rmse:5.92037
# [82]	validation-rmse:5.92004
# [83]	validation-rmse:5.92009
# [84]	validation-rmse:5.91924
# [85]	validation-rmse:5.91860
# [86]	validation-rmse:5.91816
# [87]	validation-rmse:5.91780
# [88]	validation-rmse:5.91747
# [89]	validation-rmse:5.91681
# [90]	validation-rmse:5.91673
# [91]	validation-rmse:5.91645
# [92]	validation-rmse:5.91573
# [93]	validation-rmse:5.91529
# [94]	validation-rmse:5.91464
# [95]	validation-rmse:5.91400
# [96]	validation-rmse:5.91380
# [97]	validation-rmse:5.91371
# [98]	validation-rmse:5.91359
# [99]	validation-rmse:5.91345
# [14:25:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:14.69568
# [1]	validation-rmse:12.54091
# [2]	validation-rmse:10.86724
# [3]	validation-rmse:9.58698
# [4]	validation-rmse:8.61949
# [5]	validation-rmse:7.89306
# [6]	validation-rmse:7.36268
# [7]	validation-rmse:6.97440
# [8]	validation-rmse:6.69932
# [9]	validation-rmse:6.49655
# [10]	validation-rmse:6.35287
# [11]	validation-rmse:6.24816
# [12]	validation-rmse:6.17338
# [13]	validation-rmse:6.12052
# [14]	validation-rmse:6.07879
# [15]	validation-rmse:6.04771
# [16]	validation-rmse:6.02424
# [17]	validation-rmse:6.00608
# [18]	validation-rmse:5.99208
# [19]	validation-rmse:5.98090
# [20]	validation-rmse:5.97359
# [21]	validation-rmse:5.96649
# [22]	validation-rmse:5.96178
# [23]	validation-rmse:5.95799
# [24]	validation-rmse:5.95601
# [25]	validation-rmse:5.95416
# [26]	validation-rmse:5.95250
# [27]	validation-rmse:5.94948
# [28]	validation-rmse:5.94862
# [29]	validation-rmse:5.94728
# [30]	validation-rmse:5.94497
# [31]	validation-rmse:5.94378
# [32]	validation-rmse:5.94325
# [33]	validation-rmse:5.94239
# [34]	validation-rmse:5.94171
# [35]	validation-rmse:5.93918
# [36]	validation-rmse:5.93914
# [37]	validation-rmse:5.93726
# [38]	validation-rmse:5.93687
# [39]	validation-rmse:5.93637
# [40]	validation-rmse:5.93628
# [41]	validation-rmse:5.93641
# [42]	validation-rmse:5.93629
# [43]	validation-rmse:5.93615
# [44]	validation-rmse:5.93523
# [45]	validation-rmse:5.93567
# [46]	validation-rmse:5.93507
# [47]	validation-rmse:5.93505
# [48]	validation-rmse:5.93536
# [49]	validation-rmse:5.93530
# [50]	validation-rmse:5.93522
# [51]	validation-rmse:5.93529
# [52]	validation-rmse:5.93497
# [53]	validation-rmse:5.93506
# [54]	validation-rmse:5.93509
# [55]	validation-rmse:5.93539
# [56]	validation-rmse:5.93532
# [57]	validation-rmse:5.93551
# [58]	validation-rmse:5.93589
# [59]	validation-rmse:5.93559
# [60]	validation-rmse:5.93534
# [61]	validation-rmse:5.93559
# [62]	validation-rmse:5.93583
# [63]	validation-rmse:5.93639
# [64]	validation-rmse:5.93800
# [65]	validation-rmse:5.93796
# [66]	validation-rmse:5.93751
# [67]	validation-rmse:5.93791
# [68]	validation-rmse:5.93790
# [69]	validation-rmse:5.93670
# [70]	validation-rmse:5.93682
# [71]	validation-rmse:5.93701
# [72]	validation-rmse:5.93746
# [73]	validation-rmse:5.93763
# [74]	validation-rmse:5.94116
# [75]	validation-rmse:5.94241
# [76]	validation-rmse:5.94276
# [77]	validation-rmse:5.94262
# [78]	validation-rmse:5.94256
# [79]	validation-rmse:5.94303
# [80]	validation-rmse:5.94340
# [81]	validation-rmse:5.94362
# [82]	validation-rmse:5.94673
# [83]	validation-rmse:5.94729
# [84]	validation-rmse:5.94771
# [85]	validation-rmse:5.94801
# [86]	validation-rmse:5.94825
# [87]	validation-rmse:5.94965
# [88]	validation-rmse:5.95006
# [89]	validation-rmse:5.95034
# [90]	validation-rmse:5.95071
# [91]	validation-rmse:5.95203
# [92]	validation-rmse:5.95160
# [93]	validation-rmse:5.95264
# [94]	validation-rmse:5.95292
# [95]	validation-rmse:5.95348
# [96]	validation-rmse:5.95337
# [97]	validation-rmse:5.95345
# [98]	validation-rmse:5.95455
# [99]	validation-rmse:5.95774
# [14:25:55] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:13.39725
# [1]	validation-rmse:10.67060
# [2]	validation-rmse:8.88828
# [3]	validation-rmse:7.75732
# [4]	validation-rmse:7.06916
# [5]	validation-rmse:6.64945
# [6]	validation-rmse:6.40167
# [7]	validation-rmse:6.25273
# [8]	validation-rmse:6.14979
# [9]	validation-rmse:6.08630
# [10]	validation-rmse:6.04835
# [11]	validation-rmse:6.02362
# [12]	validation-rmse:6.00225
# [13]	validation-rmse:5.98806
# [14]	validation-rmse:5.97849
# [15]	validation-rmse:5.96996
# [16]	validation-rmse:5.96185
# [17]	validation-rmse:5.95668
# [18]	validation-rmse:5.95284
# [19]	validation-rmse:5.94919
# [20]	validation-rmse:5.94776
# [21]	validation-rmse:5.94608
# [22]	validation-rmse:5.94394
# [23]	validation-rmse:5.94258
# [24]	validation-rmse:5.94243
# [25]	validation-rmse:5.94192
# [26]	validation-rmse:5.94109
# [27]	validation-rmse:5.94018
# [28]	validation-rmse:5.93964
# [29]	validation-rmse:5.93910
# [30]	validation-rmse:5.93868
# [31]	validation-rmse:5.93881
# [32]	validation-rmse:5.93699
# [33]	validation-rmse:5.93682
# [34]	validation-rmse:5.93663
# [35]	validation-rmse:5.93640
# [36]	validation-rmse:5.93665
# [37]	validation-rmse:5.93601
# [38]	validation-rmse:5.93443
# [39]	validation-rmse:5.93404
# [40]	validation-rmse:5.93427
# [41]	validation-rmse:5.93341
# [42]	validation-rmse:5.93293
# [43]	validation-rmse:5.93289
# [44]	validation-rmse:5.93293
# [45]	validation-rmse:5.93247
# [46]	validation-rmse:5.93271
# [47]	validation-rmse:5.93246
# [48]	validation-rmse:5.93234
# [49]	validation-rmse:5.93541
# [50]	validation-rmse:5.93549
# [51]	validation-rmse:5.93554
# [52]	validation-rmse:5.93545
# [53]	validation-rmse:5.93573
# [54]	validation-rmse:5.93536
# [55]	validation-rmse:5.93563
# [56]	validation-rmse:5.93611
# [57]	validation-rmse:5.93644
# [58]	validation-rmse:5.93676
# [59]	validation-rmse:5.93738
# [60]	validation-rmse:5.93745
# [61]	validation-rmse:5.93720
# [62]	validation-rmse:5.93762
# [63]	validation-rmse:5.93736
# [64]	validation-rmse:5.93821
# [65]	validation-rmse:5.93754
# [66]	validation-rmse:5.93734
# [67]	validation-rmse:5.93796
# [68]	validation-rmse:5.93765
# [69]	validation-rmse:5.93868
# [70]	validation-rmse:5.93886
# [71]	validation-rmse:5.93924
# [72]	validation-rmse:5.93960
# [73]	validation-rmse:5.93988
# [74]	validation-rmse:5.94047
# [75]	validation-rmse:5.94025
# [76]	validation-rmse:5.94032
# [77]	validation-rmse:5.94056
# [78]	validation-rmse:5.94033
# [79]	validation-rmse:5.94101
# [80]	validation-rmse:5.94139
# [81]	validation-rmse:5.94128
# [82]	validation-rmse:5.94144
# [83]	validation-rmse:5.94085
# [84]	validation-rmse:5.94088
# [85]	validation-rmse:5.94131
# [86]	validation-rmse:5.94176
# [87]	validation-rmse:5.94219
# [88]	validation-rmse:5.94279
# [89]	validation-rmse:5.94295
# [90]	validation-rmse:5.94375
# [91]	validation-rmse:5.94470
# [92]	validation-rmse:5.94562
# [93]	validation-rmse:5.94566
# [94]	validation-rmse:5.94582
# [95]	validation-rmse:5.94572
# [96]	validation-rmse:5.94625
# [97]	validation-rmse:5.94586
# [14:26:05] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.57100
# [1]	validation-rmse:15.75724
# [2]	validation-rmse:14.99795
# [3]	validation-rmse:14.29382
# [4]	validation-rmse:13.63643
# [5]	validation-rmse:13.02677
# [6]	validation-rmse:12.46309
# [7]	validation-rmse:11.93379
# [8]	validation-rmse:11.45048
# [9]	validation-rmse:11.00316
# [10]	validation-rmse:10.58725
# [11]	validation-rmse:10.20511
# [12]	validation-rmse:9.85393
# [13]	validation-rmse:9.52406
# [14]	validation-rmse:9.22514
# [15]	validation-rmse:8.95110
# [16]	validation-rmse:8.70126
# [17]	validation-rmse:8.46637
# [18]	validation-rmse:8.25420
# [19]	validation-rmse:8.05598
# [20]	validation-rmse:7.87931
# [21]	validation-rmse:7.71505
# [22]	validation-rmse:7.56605
# [23]	validation-rmse:7.43332
# [24]	validation-rmse:7.30868
# [25]	validation-rmse:7.19420
# [26]	validation-rmse:7.09097
# [27]	validation-rmse:6.99842
# [28]	validation-rmse:6.91552
# [29]	validation-rmse:6.83831
# [30]	validation-rmse:6.76839
# [31]	validation-rmse:6.70195
# [32]	validation-rmse:6.64572
# [33]	validation-rmse:6.59098
# [34]	validation-rmse:6.54214
# [35]	validation-rmse:6.49947
# [36]	validation-rmse:6.45884
# [37]	validation-rmse:6.42291
# [38]	validation-rmse:6.38827
# [39]	validation-rmse:6.35694
# [40]	validation-rmse:6.32863
# [41]	validation-rmse:6.30322
# [42]	validation-rmse:6.28062
# [43]	validation-rmse:6.25732
# [44]	validation-rmse:6.23962
# [45]	validation-rmse:6.22018
# [46]	validation-rmse:6.20422
# [47]	validation-rmse:6.18871
# [48]	validation-rmse:6.17457
# [49]	validation-rmse:6.16103
# [50]	validation-rmse:6.15024
# [51]	validation-rmse:6.13984
# [52]	validation-rmse:6.12868
# [53]	validation-rmse:6.12023
# [54]	validation-rmse:6.11024
# [55]	validation-rmse:6.10237
# [56]	validation-rmse:6.09320
# [57]	validation-rmse:6.08612
# [58]	validation-rmse:6.08125
# [59]	validation-rmse:6.07389
# [60]	validation-rmse:6.06920
# [61]	validation-rmse:6.06336
# [62]	validation-rmse:6.05879
# [63]	validation-rmse:6.05464
# [64]	validation-rmse:6.05006
# [65]	validation-rmse:6.04702
# [66]	validation-rmse:6.04346
# [67]	validation-rmse:6.03937
# [68]	validation-rmse:6.03585
# [69]	validation-rmse:6.03223
# [70]	validation-rmse:6.02932
# [71]	validation-rmse:6.02682
# [72]	validation-rmse:6.02438
# [73]	validation-rmse:6.02264
# [74]	validation-rmse:6.02007
# [75]	validation-rmse:6.01806
# [76]	validation-rmse:6.01552
# [77]	validation-rmse:6.01383
# [78]	validation-rmse:6.01242
# [79]	validation-rmse:6.01089
# [80]	validation-rmse:6.00947
# [81]	validation-rmse:6.00783
# [82]	validation-rmse:6.00657
# [83]	validation-rmse:6.00575
# [84]	validation-rmse:6.00456
# [85]	validation-rmse:6.00333
# [86]	validation-rmse:6.00236
# [87]	validation-rmse:6.00104
# [88]	validation-rmse:6.00050
# [89]	validation-rmse:5.99910
# [90]	validation-rmse:5.99786
# [91]	validation-rmse:5.99731
# [92]	validation-rmse:5.99595
# [93]	validation-rmse:5.99509
# [94]	validation-rmse:5.99444
# [95]	validation-rmse:5.99398
# [96]	validation-rmse:5.99345
# [97]	validation-rmse:5.99225
# [98]	validation-rmse:5.99138
# [99]	validation-rmse:5.99031
# [14:26:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.09748
# [1]	validation-rmse:14.89053
# [2]	validation-rmse:13.81064
# [3]	validation-rmse:12.84894
# [4]	validation-rmse:11.99216
# [5]	validation-rmse:11.23366
# [6]	validation-rmse:10.56208
# [7]	validation-rmse:9.96522
# [8]	validation-rmse:9.44341
# [9]	validation-rmse:8.98076
# [10]	validation-rmse:8.57693
# [11]	validation-rmse:8.22168
# [12]	validation-rmse:7.91586
# [13]	validation-rmse:7.64687
# [14]	validation-rmse:7.41443
# [15]	validation-rmse:7.21550
# [16]	validation-rmse:7.03970
# [17]	validation-rmse:6.88901
# [18]	validation-rmse:6.76098
# [19]	validation-rmse:6.64890
# [20]	validation-rmse:6.55249
# [21]	validation-rmse:6.46821
# [22]	validation-rmse:6.39710
# [23]	validation-rmse:6.33503
# [24]	validation-rmse:6.28025
# [25]	validation-rmse:6.23299
# [26]	validation-rmse:6.19151
# [27]	validation-rmse:6.15591
# [28]	validation-rmse:6.12706
# [29]	validation-rmse:6.10033
# [30]	validation-rmse:6.07626
# [31]	validation-rmse:6.05567
# [32]	validation-rmse:6.03752
# [33]	validation-rmse:6.02110
# [34]	validation-rmse:6.00699
# [35]	validation-rmse:5.99461
# [36]	validation-rmse:5.98333
# [37]	validation-rmse:5.97311
# [38]	validation-rmse:5.96396
# [39]	validation-rmse:5.95583
# [40]	validation-rmse:5.94859
# [41]	validation-rmse:5.94198
# [42]	validation-rmse:5.93568
# [43]	validation-rmse:5.93045
# [44]	validation-rmse:5.92586
# [45]	validation-rmse:5.92191
# [46]	validation-rmse:5.91833
# [47]	validation-rmse:5.91572
# [48]	validation-rmse:5.91263
# [49]	validation-rmse:5.91061
# [50]	validation-rmse:5.90819
# [51]	validation-rmse:5.90703
# [52]	validation-rmse:5.90553
# [53]	validation-rmse:5.90450
# [54]	validation-rmse:5.90305
# [55]	validation-rmse:5.90186
# [56]	validation-rmse:5.90083
# [57]	validation-rmse:5.89995
# [58]	validation-rmse:5.89938
# [59]	validation-rmse:5.89876
# [60]	validation-rmse:5.89729
# [61]	validation-rmse:5.89660
# [62]	validation-rmse:5.89513
# [63]	validation-rmse:5.89431
# [64]	validation-rmse:5.89348
# [65]	validation-rmse:5.89292
# [66]	validation-rmse:5.89226
# [67]	validation-rmse:5.89173
# [68]	validation-rmse:5.89032
# [69]	validation-rmse:5.88928
# [70]	validation-rmse:5.88895
# [71]	validation-rmse:5.88812
# [72]	validation-rmse:5.88765
# [73]	validation-rmse:5.88704
# [74]	validation-rmse:5.88677
# [75]	validation-rmse:5.88618
# [76]	validation-rmse:5.88584
# [77]	validation-rmse:5.88515
# [78]	validation-rmse:5.88426
# [79]	validation-rmse:5.88416
# [80]	validation-rmse:5.88373
# [81]	validation-rmse:5.88333
# [82]	validation-rmse:5.88321
# [83]	validation-rmse:5.88263
# [84]	validation-rmse:5.88237
# [85]	validation-rmse:5.88224
# [86]	validation-rmse:5.88197
# [87]	validation-rmse:5.88165
# [88]	validation-rmse:5.88121
# [89]	validation-rmse:5.88064
# [90]	validation-rmse:5.88036
# [91]	validation-rmse:5.88004
# [92]	validation-rmse:5.88016
# [93]	validation-rmse:5.87984
# [94]	validation-rmse:5.87909
# [95]	validation-rmse:5.87887
# [96]	validation-rmse:5.87871
# [97]	validation-rmse:5.87846
# [98]	validation-rmse:5.87844
# [99]	validation-rmse:5.87810
# [14:26:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:8.81318
# [1]	validation-rmse:6.67250
# [2]	validation-rmse:6.20963
# [3]	validation-rmse:6.09400
# [4]	validation-rmse:6.06104
# [5]	validation-rmse:6.05000
# [6]	validation-rmse:6.04672
# [7]	validation-rmse:6.03844
# [8]	validation-rmse:6.04015
# [9]	validation-rmse:6.02224
# [10]	validation-rmse:6.01886
# [11]	validation-rmse:6.01510
# [12]	validation-rmse:6.00819
# [13]	validation-rmse:6.00517
# ...
# [84]	validation-rmse:5.83120
# [85]	validation-rmse:5.83077
# [86]	validation-rmse:5.82899
# [87]	validation-rmse:5.82799
# [88]	validation-rmse:5.82938
# [89]	validation-rmse:5.82975
# [90]	validation-rmse:5.83030
# [91]	validation-rmse:5.83037
# [92]	validation-rmse:5.83073
# [93]	validation-rmse:5.83080
# [94]	validation-rmse:5.83022
# [95]	validation-rmse:5.82974
# [96]	validation-rmse:5.82972
# [97]	validation-rmse:5.82977
# [98]	validation-rmse:5.82945
# [99]	validation-rmse:5.82909
# [14:30:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:9.76195
# [1]	validation-rmse:7.12049
# [2]	validation-rmse:6.33953
# [3]	validation-rmse:6.10097
# [4]	validation-rmse:6.01434
# [5]	validation-rmse:5.97451
# [6]	validation-rmse:5.96182
# [7]	validation-rmse:5.94637
# [8]	validation-rmse:5.93752
# [9]	validation-rmse:5.93062
# [10]	validation-rmse:5.92507
# [11]	validation-rmse:5.92154
# [12]	validation-rmse:5.91596
# [13]	validation-rmse:5.91655
# [14]	validation-rmse:5.90364
# [15]	validation-rmse:5.90133
# [16]	validation-rmse:5.89937
# [17]	validation-rmse:5.89936
# [18]	validation-rmse:5.89845
# [19]	validation-rmse:5.89642
# [20]	validation-rmse:5.89467
# [21]	validation-rmse:5.88826
# [22]	validation-rmse:5.88659
# [23]	validation-rmse:5.88624
# [24]	validation-rmse:5.88474
# [25]	validation-rmse:5.88372
# [26]	validation-rmse:5.88036
# [27]	validation-rmse:5.87725
# [28]	validation-rmse:5.87578
# [29]	validation-rmse:5.87434
# [30]	validation-rmse:5.87406
# [31]	validation-rmse:5.87173
# [32]	validation-rmse:5.86908
# [33]	validation-rmse:5.86791
# [34]	validation-rmse:5.86737
# [35]	validation-rmse:5.86717
# [36]	validation-rmse:5.86723
# [37]	validation-rmse:5.86618
# [38]	validation-rmse:5.86368
# [39]	validation-rmse:5.86320
# [40]	validation-rmse:5.86088
# [41]	validation-rmse:5.86044
# [42]	validation-rmse:5.85772
# [43]	validation-rmse:5.85750
# [44]	validation-rmse:5.85731
# [45]	validation-rmse:5.85728
# [46]	validation-rmse:5.85703
# [47]	validation-rmse:5.85604
# [48]	validation-rmse:5.85753
# [49]	validation-rmse:5.85819
# [50]	validation-rmse:5.85363
# [51]	validation-rmse:5.85253
# [52]	validation-rmse:5.85236
# [53]	validation-rmse:5.85131
# [54]	validation-rmse:5.85213
# [55]	validation-rmse:5.85155
# [56]	validation-rmse:5.85089
# [57]	validation-rmse:5.85195
# [58]	validation-rmse:5.85275
# [59]	validation-rmse:5.85255
# [60]	validation-rmse:5.85299
# [61]	validation-rmse:5.85014
# [62]	validation-rmse:5.85093
# [63]	validation-rmse:5.85138
# [64]	validation-rmse:5.85069
# [65]	validation-rmse:5.85026
# [66]	validation-rmse:5.84998
# [67]	validation-rmse:5.84964
# [68]	validation-rmse:5.85018
# [69]	validation-rmse:5.84978
# [70]	validation-rmse:5.85015
# [71]	validation-rmse:5.84998
# [72]	validation-rmse:5.85026
# [73]	validation-rmse:5.85067
# [74]	validation-rmse:5.85013
# [75]	validation-rmse:5.84989
# [76]	validation-rmse:5.85100
# [77]	validation-rmse:5.85064
# [78]	validation-rmse:5.85083
# [79]	validation-rmse:5.85072
# [80]	validation-rmse:5.85066
# [81]	validation-rmse:5.85052
# [82]	validation-rmse:5.85030
# [83]	validation-rmse:5.84983
# [84]	validation-rmse:5.84958
# [85]	validation-rmse:5.84955
# [86]	validation-rmse:5.85327
# [87]	validation-rmse:5.85415
# [88]	validation-rmse:5.85554
# [89]	validation-rmse:5.85587
# [90]	validation-rmse:5.85558
# [91]	validation-rmse:5.85558
# [92]	validation-rmse:5.85695
# [93]	validation-rmse:5.85625
#  84%|████████▍ | 42/50 [04:49<00:55,  6.89s/trial, best loss: 5.829085365669138]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 13
#       2 search_space = {
#       3     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       4     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       9     'seed': 23
#      10 }
#      12 # best results
# ---> 13 best_result = fmin(
#      14     fn=objective,
#      15     space=search_space,
#      16     algo=tpe.suggest,
#      17     max_evals=50,
#      18     trials=Trials()
#      19 )
#
# File ~/mambaforge/envs/mlops/lib/python3.11/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/mambaforge/envs/mlops/lib/python3.11/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/mambaforge/envs/mlops/lib/python3.11/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/mambaforge/envs/mlops/lib/python3.11/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/mambaforge/envs/mlops/lib/python3.11/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/mambaforge/envs/mlops/lib/python3.11/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/mambaforge/envs/mlops/lib/python3.11/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[16], line 6, in objective(params)
#       4 mlflow.set_tag('model', 'xgboost')
#       5 mlflow.log_params(params)
# ----> 6 booster = xgb.train(
#       7     params=params,
#       8     dtrain=train,
#       9     num_boost_round=100,
#      10     evals=[(valid, 'validation')],
#      11     early_stopping_rounds=50
#      12 )
#      13 y_pred = booster.predict(valid)
#      14 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/mambaforge/envs/mlops/lib/python3.11/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/mambaforge/envs/mlops/lib/python3.11/site-packages/xgboost/training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~/mambaforge/envs/mlops/lib/python3.11/site-packages/xgboost/core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
